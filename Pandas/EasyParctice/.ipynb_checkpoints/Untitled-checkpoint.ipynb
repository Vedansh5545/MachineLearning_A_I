# %%
import numpy as np
import pandas as pd
import random

# %%
dict1 = {"name":["Harry", "Rohan", "skillaf", "shubh"],
        "marks":[12,23,45,23],
        "city": ["Ahemdabad","Indore","Pune","Kolkata"]}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks       city
# 0    Harry     12  Ahemdabad
# 1    Rohan     23     Indore
# 2  skillaf     45       Pune
# 3    shubh     23    Kolkata

# %%
df.to_csv("Friends.csv")

# %%
df2 = pd.DataFrame(np.random.rand(30,7))

# %%
df2
# Out:
#            0         1         2         3         4         5         6
# 0   0.927921  0.882387  0.321204  0.171359  0.573501  0.390311  0.790669
# 1   0.773543  0.928253  0.716987  0.061548  0.617382  0.012349  0.117957
# 2   0.611567  0.453808  0.429596  0.431536  0.452847  0.768245  0.266339
# 3   0.676067  0.217554  0.672217  0.773638  0.991453  0.740797  0.865778
# 4   0.035758  0.511418  0.891641  0.758566  0.812271  0.423225  0.039808
# 5   0.938514  0.991083  0.503552  0.419962  0.047987  0.489743  0.863909
# 6   0.255048  0.107266  0.402694  0.301419  0.901266  0.707393  0.499746
# 7   0.723113  0.963884  0.233267  0.505675  0.617746  0.385748  0.757328
# 8   0.794621  0.618434  0.964562  0.772240  0.460022  0.951529  0.448714
# 9   0.337734  0.354030  0.277944  0.359374  0.085340  0.068660  0.180947
# 10  0.175725  0.887271  0.577180  0.028035  0.976598  0.206014  0.296088
# 11  0.194864  0.178714  0.474273  0.621243  0.687744  0.852680  0.501409
# ...

# %%
df2.describe()
# Out:
#                0          1          2          3          4          5  \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    0.514610   0.498889   0.530581   0.417774   0.523660   0.520183
# std     0.310777   0.312191   0.282804   0.283252   0.305736   0.274469
# min     0.019478   0.008515   0.044435   0.010546   0.035792   0.012349
# 25%     0.259985   0.207296   0.334747   0.135852   0.276757   0.339360
# 50%     0.579513   0.510501   0.478805   0.425749   0.580808   0.533107
# 75%     0.756443   0.729539   0.723847   0.665560   0.769085   0.720291
# max     0.997976   0.991083   0.996986   0.930513   0.995943   0.968329
#
#                6
# count  30.000000
# mean    0.488997
# std     0.299066
# min     0.013234
# 25%     0.268585
# 50%     0.492938
# 75%     0.754371
# max     0.974660

# %%
dict1={
    1:np.random(),
    2:np.random(),
    3:np.random(),
}
df = pd.dataframe(dict1)
